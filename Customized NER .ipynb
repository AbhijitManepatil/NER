# %%
# en_core_web_sm(12 mb)
# en_core_web_md(43 mb)
# en_core_web_lg(741 mb)
# en_core_web_trf(438 mb)

# %%
import spacy 

nlp = spacy.load("en_core_web_sm")
#check for ner pipleine is available or not
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
#1. docx to text
import docx2txt

# extract text
# file_name="CV Wyc.docx"
file_name="VinothRajendran[6_0]-converted.docx"
text = docx2txt.process(f"./ResumeData/{file_name}")
# text
with open(f"./txtData/{file_name}.txt","w") as f:
    f.write(text)

# %%
### Test with default model

# %%
doc = nlp(text)

from spacy import displacy
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VINOTH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RAJENDRAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br></br></br></br></br></br></br></br></br></br></br></br></br>OBJECTIVE</br></br>Seeking a position where I can effectively contribute my skills as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Software Professional
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , to emerge as ‘the best’ in the field I work, there by adding value to the organization and myself.</br></br></br></br></br></br>CONTACT DETAILS</br></br></br></br>Phone: 9360958036</br></br>Email: vinothraj5112@gmail.com</br></br>Address : No :
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1B
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12th street
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  saraswathi nagar,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thiruvottiyur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , chennai - 600019</br></br></br></br></br></br></br></br>EXPERIENCE</br></br>Organization : DXC Technologies
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sep 2015 to March 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br></br>Organization : Photon Interactive
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dec 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br></br></br></br></br></br>EDUCATION</br></br>Bachelor of Computer Science (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BCA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# )
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madras University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  college</br></br>Diploma in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Computer Engineering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DCE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) Sri nallalaghu nadar polytechnic college</br></br></br></br></br></br>PERSONAL DETAILS</br></br></br></br>Father Name : Rajendran K Mother Name :
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vijaya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  R DOB :
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21 April 1996
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br></br>Year of experience :
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6.3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Years Status : Single</br></br>Nationality :
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Gender : Male</br></br>Known Language :
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tamil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br></br></br></br></br>CAREER SUMMARY</br></br></br></br>Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of experience in IT industry, including
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.5 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of experience as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cassandra Administrator
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  providing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.

# %%
for word in doc.ents:
    print(word.text," == ",word.label_)
# Out:
# VINOTH  ==  ORG
# RAJENDRAN  ==  ORG
# Software Professional  ==  ORG
# 1B  ==  CARDINAL
# 12th street  ==  FAC
# Thiruvottiyur  ==  GPE
# Sep 2015 to March 2019  ==  DATE
# April 2019  ==  DATE
# Dec 2021  ==  DATE
# BCA  ==  ORG
# Madras University  ==  ORG
# Computer Engineering  ==  ORG
# DCE  ==  ORG
# Vijaya  ==  GPE
# 21 April 1996  ==  DATE
# 6.3  ==  CARDINAL
# Indian  ==  NORP
# English  ==  LANGUAGE
# Tamil  ==  GPE
# 6 years  ==  DATE
# 3.5 years  ==  DATE
# Cassandra Administrator  ==  PERSON
# 24  ==  CARDINAL
# Apache Cassandra and Datastax Enterprise Cassandra
#
#   ==  ORG
# Cassandra  ==  GPE
# Apache Cassandra  ==  PRODUCT
# Cassandra  ==  GPE
# Cassandra Query Language  ==  PERSON
# CQL  ==  ORG
# Family’s  ==  PRODUCT
# Cassandra Worked  ==  GPE
# Cassandra Cluster  ==  PERSON
# Cassandra  Involved  ==  PERSON
# HEAP  ==  ORG
# GC  ==  ORG
# Cassandra nodes  ==  GPE
# Apache Cassandra  ==  PRODUCT
# Set Cassandra  ==  PERSON
# 24  ==  CARDINAL
# 7  ==  CARDINAL
# TECHNICAL SKILLS
#
#
#
# 	Operating Systems: Linux  ==  ORG
# Windows Languages  ==  ORG
# CQL
#
# 	  ==  ORG
# Cassandra DSE
#
# 	  ==  PERSON
# 8.2  ==  CARDINAL
# Commerce  ==  ORG
# Microsoft Azure  ==  ORG
# Jira, Service  ==  ORG
# Remedy Force
#
#
#
#   ==  PERSON
# # 1  ==  CARDINAL
# April 2019  ==  DATE
# Apache Cassandra Prod  ==  PRODUCT
# Dev  ==  PERSON
# Datacenter Cluster  ==  PERSON
# Cassandra Architecture  ==  PERSON
# Read/Write Paths  ==  ORG
# CQL Data Modelling, Replication Strategies  ==  ORG
# CASSANDRA  ==  ORG
# one  ==  CARDINAL
# 10  ==  CARDINAL
# DataStax  ==  ORG
# SLA  ==  ORG
# DataStax  ==  ORG
# # 2  ==  CARDINAL
# AT&T  ==  ORG
# Sep 2015 to March 2019  ==  DATE
# 1  ==  CARDINAL
# Clearing  ==  ORG
# DEV  ==  ORG
# Code  ==  ORG
# P1  ==  ORG
# SNOW  ==  ORG
# DECLARATION
#
#
#
#   ==  PERSON
# Rajendran  ==  GPE

# %%
# explain about TAGS
spacy.explain("GPE")
# Out:
# 'Countries, cities, states'

# %% [markdown]
# ## Custom NER:
# SpaCy pre-trained models detect and categorize the text chunks into 18 types of entities.
#
# Steps to build the custom NER model for detecting the job role in job postings in spaCy 3.0:
#
# 1. Annotate the data to train the model.
# 2. Convert the annotated data into the spaCy bin object.
# 3. Generate the config file from the spaCy website.
# 4. Train the model in the command line.
# 5. Load and test the saved model.

# %%
#2. Annotate the txt file

# %%
#3. Convet .jsonl to .spacy

# %%
#select file
jsonl_file="root.jsonl"

annotation_file_name=f"./AnnotationJSONL/{jsonl_file}"

# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm
import logging
import json

#filtter data to convert in spacy format
def fillterDoccanoData(doccano_JSONL_FilePath):
    try:
        training_data = []
        lines=[]
        with open(doccano_JSONL_FilePath, 'r') as f:
            lines = f.readlines()

        for line in lines:
            data = json.loads(line)
            text = data['data']
            entities = data['label']
            if len(entities)>0:
                training_data.append((text, {"entities" : entities}))
        return training_data
    except Exception as e:
        logging.exception("Unable to process " + doccano_JSONL_FilePath + "\n" + "error = " + str(e))
        return None

# %%
#read Doccano Annotation file .jsonl
TRAIN_DATA=fillterDoccanoData(annotation_file_name) #root.jsonl is annotation file name file name 

nlp = spacy.blank("en") # load a new spacy model
db = DocBin() # create a DocBin object
for text, annot in tqdm(TRAIN_DATA): # data in previous format
    doc = nlp.make_doc(text) # create doc object from text
    ents = []
    for start, end, label in annot["entities"]: # add character indexes
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    try:
        doc.ents = ents # label the text with the ents
        db.add(doc)
    except:
        print(text, annot)
db.to_disk("./SpaCyTrainData/roottrain.spacy") # save the docbin object
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 60.95it/s]

# %%
#4. Load Config file
# https://spacy.io/usage/training

# %%
# !python -m spacy init config --lang en --pipeline ner configV.cfg --force
# Out:
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: en
# - Pipeline: ner
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# configV.cfg
# You can now add your data and train your pipeline:
# python -m spacy train configV.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
#5. Train model

# %%
# !python -m spacy train configV.cfg --output ./training/ --paths.train ./SpaCyTrainData/roottrain.spacy --paths.dev ./SpaCyTrainData/Vdev.spacy --training.eval_frequency 10 --training.max_steps 100 --gpu-id -0


#Explain:
#<python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy>
#Dev --> Validation Data 
#train --> Training Data
# Out:
# ℹ Saving to output directory: training
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2022-04-01 15:50:18,551] [INFO] Set up nlp object from config
# [2022-04-01 15:50:18,559] [INFO] Pipeline: ['tok2vec', 'ner']
# [2022-04-01 15:50:18,562] [INFO] Created vocabulary
# [2022-04-01 15:50:18,562] [INFO] Finished initializing nlp object
# [2022-04-01 15:50:19,156] [INFO] Initialized pipeline components: ['tok2vec', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00    454.24    0.00    0.00    0.00    0.00
#  10      10         24.70   7631.21    0.00    0.00    0.00    0.00
#  20      20        249.90   1025.85    0.00    0.00    0.00    0.00
#  30      30        607.49    677.43    8.89   28.57    5.26    0.09
#  40      40        204.32    467.24    0.00    0.00    0.00    0.00
#  50      50        192.19    530.43   14.08   15.15   13.16    0.14
#  60      60        226.57    489.88   55.07   61.29   50.00    0.55
#  70      70         39.60    282.31   26.09   75.00   15.79    0.26
#  80      80        103.26    303.89   66.67   74.19   60.53    0.67
#  90      90          4.88     56.56   78.87   84.85   73.68    0.79
# 100     100          0.33      1.93   78.87   84.85   73.68    0.79
# ✔ Saved pipeline to output directory
# training/model-last

# %%
#load trained custom model

# %%
custNlp = spacy.load(r"./training/model-best") #load the best model

# %%
#Test on Existing Data

# %%
import docx2txt
Cv_PathToTest="./ResumeData/CV Wyc.docx"
cv_text = docx2txt.process(Cv_PathToTest)

doc = custNlp(cv_text) # input sample tex

spacy.displacy.render(doc, style="ent", jupyter=True) # display in Jupyter
# [(X, X.ent_type_) for X in doc if X.ent_type_]
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">CURRICULUM VITAE SUMMARY</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wycliff Kabogo Atunga	                                           +256 756104040		              kawycliff3@gmail.com
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# OBJECTIVE:</br></br></br></br>I seek to work in an organization where i will contribute to its objectives, support its clients and learn continuously.</br></br></br></br>A highly organized
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Supply Chain Management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  Executive with over 10 years of experience spearheading International Procurement Sourcing, Formulating of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Multi-
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# clientele Acquisition Plans, Negotiating Global Contracts, Scheduling Multi-national projects
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Supply Chain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  activities , Integrating and consolidating acquisition processes through ERP system,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Material Resource Planning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  (MRP), Establishing new procurement partnerships, designing and implementing acquisition processes such as local bid evaluation processing, enhancing supplier relationship, bench-marking, assets management, Shipping and clearing, fleet management and Sustainable purchasing policies for goods, services and works projects, inventory and warehousing control, deliveries and material inspections. Under my current position am managing and guiding a team of more than 15 acquisition personnel both at local and international offices in Togo, Ghana,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Liberia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     South Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gambia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# , Uganda and India</br></br>EDUCATION BACKGROUND:</br></br></br></br>2015 – Certified International
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Supply Chain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  Management Professional (CISCP) – IPSCMI (International Purchasing and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Supply Chain Management Institute- Delaware,
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  United States.</br></br></br></br>2002 – 2005
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bachelor of Business Administration – MUBS (Makerere University Business School)
#
# WORK EXPERIENCE
#
# Head – Global Supply Chain (Acquisition &amp; Logistics)
#
# Tax-link Services Ltd | TSL (International Procurement Out-Sourcing Corporation)
#
# Oct 2020 – Present (2 years)
#
# Achievements:
#
# Overall overseeing of comprehensive international procurement activities—including supplier selection, contract negotiation, cost reporting, and estimating—Forecasting product needs through close communication with more than 50 Multi-national Clients and suppliers world-wide.
#
# Establishment of new procurement partnerships across Africa, bringing Uganda, Togo, Liberia, Ghana, Gambia, South Africa, South Sudan onboard for new clients procuring an estimate of $10 million worth of products
#
# Successfully established supplier relationship base with More than 80 reliable and reputable manufactures and suppliers from China, India, Malaysia, Bangladesh, Singapore, Russia, Iran, Dubai, Turkey, Egypt, France, UK, USA, Japan and others.
#
# Introduced and Implemented innovative Supply Chain system to monitor actions processed through procurement and logistic support system such as MRP to enhance systematic Client order requests, supplier communications, Buyer payment processing, Shipping coordination, delivery updates as well as Coordinating staff training and management functions to stimulate top-flight team performance and ensure strict compliance with regulations and guidelines.
#
# Roles:
#
# Developing strategic acquisition plan and procedures and provide oversight to procurement teams for both Uganda and international offices on implementation, system development and optimization of projects management.
#
# Provision of guidance to clients, manufacturers, suppliers, staff and management personnel on product specifications, acquisition processes, shipping and tax assessments, manufacturing capabilities international customs laws and project status throughout acquisition stages.
#
# Building and maintaining relationships with buyers and suppliers both locally and internationally.
#
# High Stake price and contract negotiations with procurement partners and international manufactures
#
# Perform global market research to gather information about commercial practices, availability of products, government laws on international procurement procedures and guidelines.
#
# Coordinate a range of acquisition activities, and supported planning analysis for both local and international clients.
#
# Participating in earned value management reviews and future acquisition strategy boards used in establishing baselines for operations of future goals.
#
# Developed forecasting, coordinating and implementation of logistics support guidelines including budgets and manpower requirements
#
# Performing analysis of logistics support requirements and resource shortfalls for assigned missions.
#
# Formulating strategic local and international sourcing technics to arrive at reliable suppliers quickly
#
# Ensuring product quality assurance, supplier compliance to terms of requests by the importers
#
# Overseeing overall supply chain activities both locally and at international offices.
#
# Budget formulations, monitoring procurement expenditures and internal costs controls set up
#
# Monitoring client’s acquisition plans, progre

# %%
## Test with New Data

# %%
import docx2txt
Cv_PathToTest="./ResumeData/Balaji[5_8].docx"
cv_text = docx2txt.process(Cv_PathToTest)

doc = custNlp(cv_text) # input sample tex

spacy.displacy.render(doc, style="ent", jupyter=True) # display in Jupyter
# [(X, X.ent_type_) for X in doc if X.ent_type_]
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Balaji MC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#             Mobile:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +91–6301539560
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CompanyName</span>
# </mark>
#               balajimc999@gmail.com </br></br>														</br></br>														Technical Summary:</br></br>														</br></br>Having 5+ years of total experience as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     multiple Database Administrator on
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cassandra &amp;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  Oracle.</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Expertise in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  strong analytical problem-solving, organizational, communication, learning and team skills.</br></br>Extensively Worked on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cassandra NoSQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  Database.</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     End-to- end performance tuning of Cassandra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CollegeName</span>
# </mark>
#  clusters against very large data sets</br></br>Installation and configuration of Open-Source Apache Cassandra</br></br>Hands on experience in configuring, adding, removing, upgrading and decommissioning Cassandra nodes</br></br>Start, Stop and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monitor of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  Cassandra nodes using tools like node tool.</br></br>Extensively Used Cassandra utility sstableloader to load Big Tables.</br></br>														Good experience in Oracle Installations and Oracle database creation using DBCA and Manually.</br></br>													Schema management, creating and maintaining logins, synonyms, grant privileges and creating roles that can be granted to users or to other roles, controlling access to the database using Oracle security features.</br></br>														Handled database backups using EXPDP/IMPDP utilities.</br></br>														Configuring and managing backup through RMAN utility.</br></br>														Experience in backups and recovery and cloning of databases using RMAN.</br></br>														Experience in Configuring and maintaining Physical standby databases.</br></br>Experience in switchover and failover in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data guard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# .</br></br>														Experienced in Oracle support processes in logging service requests and other support Procedures.</br></br>														Worked in 24x7 production environment and provided on-call and day-to-day support.</br></br>														</br></br>														Experience Summary:</br></br>														</br></br>													worked as an Oracle &amp; Cassandra Database Administrator with Wipro Technologies, from November 2015 to till date.</br></br>													</br></br>														Educational Qualification:</br></br>														</br></br>														Completed Master of Computer Applications from the Periyar University in the year 2009.</br></br>													</br></br>													DataStax Certification:</br></br>													</br></br>													          Certification on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apache Cassandra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  3
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Administrator Associate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  </br></br>														</br></br>														</br></br>														</br></br>														</br></br>														</br></br>														</br></br>Skill set:</br></br>														</br></br>Operating Systems		:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RHEL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sun Solaris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# </br></br>Databases			: 11g &amp; 12c</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Languages
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# : CQL,SQL</br></br>Tools &amp; Utilities		: nodetool,RMAN,Putty,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data Pump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# ,expdp/impdp</br></br>Ticketing Tools		:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Remedy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# , ServiceNow</br></br>Console			: AWS</br></br></br></br>														</br></br>														</br></br>														</br></br>														</br></br>														Project Based Experience:</br></br>														</br></br>																				Project: XEROX</br></br>														</br></br>

# %%
########################33

############TEST

# !python -m spacy train configV.cfg --output ./trainingTEST/ --paths.train ./SpaCyTrainData/Vtrain.spacy --paths.dev ./SpaCyTrainData/Bdev.spacy --training.eval_frequency 10 --training.max_steps 100 --gpu-id -0


#Explain:
#<python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy>
#Dev --> Validation Data 
#train --> Training Data
# Out:
# ✔ Created output directory: trainingTEST
# ℹ Saving to output directory: trainingTEST
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2022-03-31 16:46:14,364] [INFO] Set up nlp object from config
# [2022-03-31 16:46:14,371] [INFO] Pipeline: ['tok2vec', 'ner']
# [2022-03-31 16:46:14,373] [INFO] Created vocabulary
# [2022-03-31 16:46:14,373] [INFO] Finished initializing nlp object
# [2022-03-31 16:46:14,773] [INFO] Initialized pipeline components: ['tok2vec', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00    456.74    0.00    0.00    0.00    0.00
#  10      10         24.50   7613.03    0.00    0.00    0.00    0.00
#  20      20        247.95   1098.15    0.00    0.00    0.00    0.00
#  30      30       1178.33    892.60    0.00    0.00    0.00    0.00
#  40      40        178.04    573.43    0.00    0.00    0.00    0.00
#  50      50         11.68    529.78    0.00    0.00    0.00    0.00
#  60      60         70.59    519.80    6.90   28.57    3.92    0.07
#  70      70         71.21    431.23    9.38   23.08    5.88    0.09
#  80      80          9.91    155.45   12.31   28.57    7.84    0.12
#  90      90         22.63    131.09    9.38   23.08    5.88    0.09
# 100     100          2.12     15.75    9.68   27.27    5.88    0.10
# ✔ Saved pipeline to output directory
# trainingTEST/model-last

# %%
custNlp_1 = spacy.load(r"./trainingTEST/model-best") #load the best model

# %%
import docx2txt
Cv_PathToTest="./ResumeData/VinothRajendran[6_0]-converted.docx"
cv_text = docx2txt.process(Cv_PathToTest)

doc = custNlp_1(cv_text) # input sample tex

spacy.displacy.render(doc, style="ent", jupyter=True) # display in Jupyter
# [(X, X.ent_type_) for X in doc if X.ent_type_]
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VINOTH	RAJENDRAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Name</span>
# </mark>
# </br></br></br></br></br></br></br></br></br></br></br></br></br></br>OBJECTIVE</br></br>Seeking a position where I can effectively contribute my skills as Software Professional, to emerge as ‘the best’ in the field I work, there by adding value to the organization and myself.</br></br></br></br></br></br>CONTACT DETAILS</br></br></br></br>Phone:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9360958036
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PhoneNumber</span>
# </mark>
# </br></br>Email:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vinothraj5112@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Email</span>
# </mark>
# </br></br>Address : No : 1B, 12th street saraswathi nagar, Thiruvottiyur,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chennai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Location</span>
# </mark>
#  - 600019</br></br></br></br></br></br></br></br>EXPERIENCE</br></br>Organization :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DXC Technologies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CompanyName</span>
# </mark>
#  Sep 2015 to March 2019</br></br>Organization :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Photon Interactive
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CompanyName</span>
# </mark>
#  April 2019 to Dec 2021</br></br></br></br></br></br>EDUCATION</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bachelor of Computer Science (BCA)
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Degree</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madras University college
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CollegeName</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diploma in Computer Engineering (DCE)
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Degree</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sri nallalaghu nadar polytechnic college
#
#
#
#
#
# PERSONAL DETAILS
#
#
#
# Father Name : Rajendran K Mother Name : Vijaya R
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CollegeName</span>
# </mark>
#  DOB : 21 April 1996</br></br>Year of experience :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6.3 Years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TotalExperience</span>
# </mark>
#  Status : Single</br></br>Nationality : Indian Gender : Male</br></br>Known Language :
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Language</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tamil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Language</span>
# </mark>
# </br></br></br></br></br>CAREER SUMMARY</br></br></br></br>Over 6 years of experience in IT industry, including 3.5 years of experience as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cassandra Administrator
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Designation</span>
# </mark>
#  providing 24*7 production database support with Support to developers &amp; end - users on call support &amp; co-ordination with off shore teams.</br></br>In depth knowledge of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apache Cassandra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Datastax Enterprise Cassandra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# </br></br>In depth knowledge in Cassandra read, writes paths and internal architecture .</br></br>Experience with installing, configuring and monitoring
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apache Cassandra cluster
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# .</br></br>Experience in implementing
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     multi-datacenter cluster
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  .</br></br>Designing data models in Cassandra and working with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cassandra Query Language (CQL)
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# .</br></br>Worked in creating column Family’s;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bootstrapping
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin:
